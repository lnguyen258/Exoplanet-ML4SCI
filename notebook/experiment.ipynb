# %%
import os
import warnings
from pathlib import Path

# --- Working directory ---
PROJECT_DIR = Path().resolve()
PROJECT_ROOT_NAME = 'exxa'

while PROJECT_DIR.name != PROJECT_ROOT_NAME and PROJECT_DIR != PROJECT_DIR.parent:
    PROJECT_DIR = PROJECT_DIR.parent

if Path().resolve() != PROJECT_DIR:
    os.chdir(PROJECT_DIR)

# %%
import matplotlib.pyplot as plt
from PIL import Image
from src.utils import DiskDataset 


dataset = DiskDataset('data/train')
sample_image = dataset[0]

plt.imshow(sample_image, cmap='magma') 
plt.axis('off') 
plt.title('Sample')
plt.show()
